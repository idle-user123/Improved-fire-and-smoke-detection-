# %%
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17067, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 17067 (delta 24), reused 27 (delta 12), pack-reused 17022 (from 1)
# Receiving objects: 100% (17067/17067), 15.68 MiB | 7.04 MiB/s, done.
# Resolving deltas: 100% (11714/11714), done.
# /content/yolov5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.4/898.4 kB 45.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.5 MB/s eta 0:00:00
# Setup complete. Using torch 2.5.1+cu121 (Tesla T4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# !unzip "/content/drive/MyDrive/dataset.zip" -d "/content/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/images/test/outside3007.jpg
#   inflating: /content/images/test/inside849.jpg
#   inflating: /content/images/test/outside1408.jpg
#   inflating: /content/images/test/outside775.jpg
#   inflating: /content/images/test/outside284.jpg
#   inflating: /content/images/test/outside2981.jpg
#   inflating: /content/images/test/inside160.jpg
#   inflating: /content/images/test/outside1359.jpg
#   inflating: /content/images/test/inside969.jpg
#   inflating: /content/images/test/inside1255.jpg
#   inflating: /content/images/test/outside214.jpg
#   inflating: /content/images/test/outside605.jpg
#   inflating: /content/images/test/inside106.jpg
#   inflating: /content/images/test/inside952.jpg
#   inflating: /content/images/test/inside1506.jpg
#   inflating: /content/images/test/outside1030.jpg
#   inflating: /content/images/test/outside3330.jpg
#   inflating: /content/images/test/outside1539.jpg
# ...

# %%
yaml_content = """
train: /content/images/train
val: /content/images/val
nc: 2
names: ['fire', 'smoke']
"""

with open('/content/dataset.yaml', 'w') as f:
    f.write(yaml_content)

# %%
# !python train.py --img 640 --batch 16 --epochs 15 --data /content/dataset.yaml --weights yolov5s.pt
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#        3/14       4.4G    0.04984    0.03504    0.01596         72        640:  75% 164/219 [01:07<00:19,  2.85it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/14       4.4G    0.04982    0.03506    0.01597         80        640:  75% 165/219 [01:07<00:17,  3.07it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/14       4.4G    0.04983    0.03509    0.01594         82        640:  76% 166/219 [01:07<00:19,  2.76it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !python val.py --weights runs/train/exp/weights/last.pt --data /content/dataset.yaml --img 640
# Out:
# val: data=/content/dataset.yaml, weights=['runs/train/exp/weights/last.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-388-g882c35fc Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/labels/val.cache... 495 images, 0 backgrounds, 0 corrupt: 100% 495/495 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 16/16 [00:08<00:00,  1.79it/s]
#                    all        495       1158       0.59      0.567      0.561      0.311
#                   fire        495        662      0.517        0.6      0.554      0.275
# ...
